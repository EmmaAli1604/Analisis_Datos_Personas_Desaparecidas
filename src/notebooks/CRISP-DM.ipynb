# %% [markdown]
# # CRISP-DM

# %% [markdown]
# ----
# En este notebook se debe de anotar lo del CRISP y sus fases

# %% [markdown]
# ## Business Undestandig

# %% [markdown]
# ## Data Understanding

# %% [markdown]
# ## Data Preparation

# %% [markdown]
# ## Modelling

# %% [markdown]
# ## Evaluation

# %% [markdown]
# ## Deployment
