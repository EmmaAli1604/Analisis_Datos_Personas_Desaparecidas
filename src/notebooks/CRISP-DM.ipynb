# %% [markdown]
# # CRISP-DM

# %% [markdown]
# ----
# En este notebook se va a encontrar las fases del CRISP-DM y como se fueron implementando en el dataset

# %% [markdown]
# ## Business Undestandig

# %% [markdown]
# definir el objetivo, las preguntas de análisis y los criterios de
# éxito.

# %% [markdown]
# ## Data Understanding

# %% [markdown]
# Understanding: realizar la exploración inicial del dataset, evaluar su calidad y
# plantear hipótesis preliminares.

# %% [markdown]
# ## Data Preparation

# %% [markdown]
# describir las tareas de limpieza, transformación, selección de varia-
# bles y creación de variables derivadas.

# %% [markdown]
# ## Modelling

# %% [markdown]
# aunque no se entrenen modelos, indicar qué técnica de minería de datos
# sería adecuada para este caso.

# %% [markdown]
# ## Evaluation

# %% [markdown]
# explicar cómo se validarían los hallazgos, qué sesgos o limitaciones po-
# drían existir y cuáles serían los criterios de utilidad.

# %% [markdown]
# ## Deployment

# %% [markdown]
# describir cómo se entregaría el análisis final, por ejemplo, mediante un
# reporte.
